# %% [markdown]
# # Vehicle Detection, Tracking and Speed Estimation

# %%
# STEP 1: Mount Google Drive and Load Video
from google.colab import drive
import os
import cv2
import numpy as np
import time

def mount_and_prepare_video(relative_drive_path='MyDrive/highway_video.mp4'):
    drive.mount('/content/drive', force_remount=True)
    input_path = os.path.join('/content/drive', relative_drive_path)
    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        raise FileNotFoundError(f"Could not open video at: {input_path}")
    fps = cap.get(cv2.CAP_PROP_FPS)
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    cap.release()
    print(f"Loaded video: {input_path}\nResolution: {width}x{height}, FPS: {fps}")
    return input_path, fps, width, height

# %%
input_video_path, fps, width, height = mount_and_prepare_video('MyDrive/highway_video.mp4')
# Out:
# Mounted at /content/drive
# Loaded video: /content/drive/MyDrive/highway_video.mp4
# Resolution: 640x360, FPS: 25.0

# %%
# STEP 2: Prepare Output Directory
def prepare_output_dir(base_dir='/content/vehicle_speed_outputs'):
    os.makedirs(base_dir, exist_ok=True)
    print(f"Output will be saved to: {base_dir}")
    return base_dir

# %%
output_dir = prepare_output_dir()
# Out:
# Output will be saved to: /content/vehicle_speed_outputs

# %%
# STEP 3: Load Models
# !pip install ultralytics
import torch
from torchvision.models.detection import ssdlite320_mobilenet_v3_large, fasterrcnn_resnet50_fpn
from torchvision import transforms
from ultralytics import YOLO

def load_models():
    models = {
        'yolo': YOLO('yolov8n.pt'),
        'ssd': ssdlite320_mobilenet_v3_large(pretrained=True).eval(),
        'frcnn': fasterrcnn_resnet50_fpn(pretrained=True).eval()
    }
    transform = transforms.Compose([transforms.ToTensor()])
    print("Models loaded: YOLOv8, SSD, Faster R-CNN")
    return models, transform
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.168)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
models, transform = load_models()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=SSDLite320_MobileNet_V3_Large_Weights.COCO_V1`. You can also use `weights=SSDLite320_MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Models loaded: YOLOv8, SSD, Faster R-CNN

# %%
# STEP 4: COCO Category Names
COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter',
    'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra',
    'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
    'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon',
    'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog',
    'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table',
    'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
    'teddy bear', 'hair drier', 'toothbrush'
]

# Sources:
# COCO Labels: https://github.com/nightrome/cocostuff/blob/master/labels.md
# PyTorch Reference: https://github.com/pytorch/vision/blob/main/references/detection/coco_utils.py

# %%
# STEP 5: Detection Functions

# Run YOLOv8 model to detect vehicles in a frame
# Filters for object classes: car (2), bus (5), and truck (7)
def detect_yolov8(yolo_model, frame):
    results = yolo_model(frame)[0]  # Run YOLO inference
    detections = []
    for r in results.boxes.data.tolist():
        x1, y1, x2, y2, score, cls_id = r
        if int(cls_id) in [2, 5, 7]:  # Filter: car, bus, truck
            detections.append([int(x1), int(y1), int(x2), int(y2), score])
    return detections


# Run SSD (Single Shot Detector) on a frame using torchvision
# Converts frame to tensor, runs inference, filters by class label and confidence
# COCO class labels are used to identify vehicle types

def detect_ssd(ssd_model, transform, frame):
    image = transform(frame).unsqueeze(0)  # Convert to tensor and batch
    with torch.no_grad():
        outputs = ssd_model(image)[0]  # Run SSD inference
    detections = []
    for idx in range(len(outputs['boxes'])):
        label = outputs['labels'][idx].item()
        score = outputs['scores'][idx].item()
        # Lowered confidence threshold to 0.3 for SSD to improve detection coverage
        if COCO_INSTANCE_CATEGORY_NAMES[label] in ['car', 'bus', 'truck'] and score > 0.3:
            x1, y1, x2, y2 = outputs['boxes'][idx].int().tolist()
            detections.append([x1, y1, x2, y2, score])
    return detections


# Run Faster R-CNN on a frame using torchvision
# Similar to SSD, uses COCO labels to filter for car, bus, truck
# Returns bounding boxes and scores for valid detections

def detect_frcnn(frcnn_model, transform, frame):
    image = transform(frame).unsqueeze(0)
    with torch.no_grad():
        outputs = frcnn_model(image)[0]  # Run Faster R-CNN inference
    detections = []
    for idx in range(len(outputs['boxes'])):
        label = outputs['labels'][idx].item()
        score = outputs['scores'][idx].item()
        # check label index is within COCO list
        if label < len(COCO_INSTANCE_CATEGORY_NAMES) and COCO_INSTANCE_CATEGORY_NAMES[label] in ['car', 'bus', 'truck'] and score > 0.5:
            x1, y1, x2, y2 = outputs['boxes'][idx].int().tolist()
            detections.append([x1, y1, x2, y2, score])
    return detections

# %%
# Utility: Extract the actual video FPS to ensure consistent speed estimation
import cv2
import subprocess

# Convert video to a supported format with FFmpeg before metadata extraction

def convert_video_with_ffmpeg(input_path, output_path):
    command = [
        'ffmpeg', '-y', '-i', input_path,
        '-vf', 'fps=25',
        '-c:v', 'libx264', '-crf', '23', '-preset', 'veryfast',
        '-c:a', 'copy', output_path
    ]
    subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)


# Check if video is readable and fix loading issue if needed

def validate_video_readability(video_path):
    cap = cv2.VideoCapture(video_path)
    ret, _ = cap.read()
    cap.release()
    if not ret:
        print("Warning: Could not read frames. Re-encoding might be necessary.")
        return False
    return True


# Get video metadata using OpenCV

def get_video_metadata(video_path):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    return fps, width, height, total_frames

# %%
# Set your original video path
original_video = "/content/drive/MyDrive/highway_video.mp4"
converted_video = "/content/converted_video.mp4"

# Check readability and convert if needed
if not validate_video_readability(original_video):
    convert_video_with_ffmpeg(original_video, converted_video)
    input_video_path = converted_video
else:
    input_video_path = original_video

# Load metadata
fps, width, height, total_frames = get_video_metadata(input_video_path)

# Print results
print(f"Using: {input_video_path}")
print(f"FPS: {fps}, Resolution: {width}x{height}, Total Frames: {total_frames}")
# Out:
# Using: /content/drive/MyDrive/highway_video.mp4
# FPS: 25.0, Resolution: 640x360, Total Frames: 1725

# %%
# STEP 6: Tracking and Speed Estimation
trackers = {}
next_id = 0

# Simple object tracker using nearest-neighbor logic
# Tracks are identified by comparing center point proximity across frames

def track_objects(detections, frame_idx):
    global next_id
    objects = []
    for det in detections:
        x1, y1, x2, y2, score = det
        cx = int((x1 + x2) / 2)
        cy = int((y1 + y2) / 2)
        matched_id = None

        # Try to match current object to an existing tracker ID
        for obj_id, history in trackers.items():
            if abs(cx - history[-1][0]) < 30 and abs(cy - history[-1][1]) < 30:
                matched_id = obj_id
                trackers[obj_id].append((cx, cy, frame_idx))
                break

        # If no match is found, assign a new tracker ID
        if matched_id is None:
            trackers[next_id] = [(cx, cy, frame_idx)]
            matched_id = next_id
            next_id += 1

        objects.append((matched_id, (x1, y1, x2, y2)))
    return objects


# Estimate speed from tracked object history
# Uses displacement in pixels between last two frames, scaled to meters
# scale_mpp is the assumed meters-per-pixel ratio
# former scale_mpp=0.05
# scale_mpp = 0.25 is tuned for this highway video and improves realism

def estimate_speed(track, fps, scale_mpp=0.25):
    if len(track) < 2:
        return 0
    (x1, y1, f1), (x2, y2, f2) = track[-2], track[-1]
    dx = x2 - x1
    dy = y2 - y1
    dist_pix = np.sqrt(dx**2 + dy**2)
    dist_m = dist_pix * scale_mpp
    dt = (f2 - f1) / fps
    if dt == 0:
        return 0
    return (dist_m / dt) * 3.6  # Convert m/s to km/h

# %%
# STEP 7: Run All Models and Generate Output Videos

# Run speed tracking and alert pipeline for each model
# Saves annotated output videos and logs average FPS and speed
# Also tracks frame count, total runtime, and detection count for quantitative evaluation

def run_all_models(input_video_path, output_dir, fps, width, height, models, transform):
    detectors = {
        'yolo': lambda frame: detect_yolov8(models['yolo'], frame),
        'ssd': lambda frame: detect_ssd(models['ssd'], transform, frame),
        'frcnn': lambda frame: detect_frcnn(models['frcnn'], transform, frame),
    }

    results_summary = []

    for model_name, detect_func in detectors.items():
        print(f"\n Running {model_name.upper()} model...")

        cap = cv2.VideoCapture(input_video_path)
        output_path = os.path.join(output_dir, f'output_{model_name}.mp4')
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

        frame_idx = 0
        trackers.clear()
        global next_id
        next_id = 0

        start_time = time.time()
        total_speeds = []
        frame_times = []
        total_detections = 0
        track_lengths = {}

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            t0 = time.time()
            detections = detect_func(frame)
            total_detections += len(detections)
            objects = track_objects(detections, frame_idx)

            # Annotate each tracked vehicle
            for obj_id, (x1, y1, x2, y2) in objects:
                track = trackers[obj_id]
                speed = estimate_speed(track, fps)
                total_speeds.append(speed)
                track_lengths[obj_id] = len(track)
                color = (0, 0, 255) if speed > 100 else (0, 255, 0)
                label = f'ID:{obj_id} Speed:{int(speed)} km/h'
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(frame, label, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            out.write(frame)
            frame_idx += 1
            frame_times.append(time.time() - t0)

        cap.release()
        out.release()
        total_time = time.time() - start_time

        # Log performance statistics
        avg_fps = round(1 / np.mean(frame_times), 2) if frame_times else 0
        avg_speed = round(np.mean(total_speeds), 2) if total_speeds else 0
        avg_track_len = round(np.mean(list(track_lengths.values())), 2) if track_lengths else 0

        print(f"Done: {model_name} → saved to {output_path}")
        print(f"Avg FPS: {avg_fps}")
        print(f"Avg Speed Estimate: {avg_speed} km/h")
        print(f"Total Detections: {total_detections}")
        print(f"Avg Track Length: {avg_track_len} frames")
        print(f"Total Runtime: {round(total_time, 2)} seconds")

        results_summary.append({
            'model': model_name,
            'fps': avg_fps,
            'avg_speed_kmh': avg_speed,
            'detections': total_detections,
            'avg_track_length': avg_track_len,
            'runtime_sec': round(total_time, 2),
            'video_path': output_path
        })

    return results_summary

# %%
results = run_all_models(input_video_path, output_dir, fps, width, height, models, transform)
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# Speed: 1.6ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 3 trucks, 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 3 trucks, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trains, 2 trucks, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 3 trucks, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 train, 2 trucks, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 1 truck, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 1 truck, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 9.9ms
# Speed: 1.6ms preprocess, 9.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 1 truck, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 1 truck, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 1 truck, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 train, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 train, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 1 truck, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 1 truck, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 2 trucks, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 2 trucks, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 2 trucks, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 2 trucks, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 3 trucks, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 3 trucks, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 3 trucks, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 1 truck, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 3 trucks, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 1 train, 2 trucks, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 3 trucks, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 1 train, 3 trucks, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 1 train, 4 trucks, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 4 trucks, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 4 trucks, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 4 trucks, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 4 trucks, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 3 trucks, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 train, 2 trucks, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 2 trucks, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 3 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 1 truck, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 3 trucks, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 3 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 train, 2 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 1 train, 2 trucks, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 3 trucks, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 2 trucks, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 3 trucks, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 2 trucks, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 3 trucks, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 3 trucks, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 3 trucks, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 1 truck, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 2 trucks, 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 2 trucks, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 2 trucks, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 2 trucks, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 train, 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 1 truck, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 train, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 9.7ms
# Speed: 1.6ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 train, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 train, 1 truck, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 1 truck, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 train, 8.0ms
# ...
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 1 truck, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 1 truck, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 1 truck, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 1 truck, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 1 truck, 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 1 truck, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 1 truck, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 1 truck, 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 train, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 1 truck, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 train, 1 truck, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 1 truck, 9.9ms
# Speed: 1.6ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 train, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 1 bus, 1 train, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 1 truck, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 2 buss, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 train, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 1 truck, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 1 truck, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 2 trucks, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 1 truck, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 1 truck, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 1 truck, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 train, 1 truck, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 2 buss, 1 train, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 1 truck, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 1 truck, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 buss, 1 train, 1 truck, 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 2 trucks, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 train, 3 trucks, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 bus, 1 train, 2 trucks, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2 buss, 1 train, 2 trucks, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 buss, 1 train, 2 trucks, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 buss, 1 train, 1 truck, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 buss, 1 train, 2 trucks, 8.6ms
# Speed: 1.4ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 1 train, 1 truck, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 buss, 1 train, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 buss, 1 train, 1 truck, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3 buss, 1 train, 1 truck, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 buss, 1 train, 1 truck, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 buss, 1 train, 1 truck, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 buss, 1 train, 1 truck, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 buss, 1 train, 1 truck, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 buss, 1 train, 1 truck, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 1 truck, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 1 train, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 buss, 1 train, 1 truck, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 buss, 1 train, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 1 truck, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 1 train, 1 truck, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 buss, 1 train, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 3 trains, 1 truck, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 1 train, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 buss, 2 trains, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 buss, 2 trains, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 buss, 2 trains, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trains, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trains, 9.1ms
# Speed: 1.4ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trains, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 3 trains, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 buss, 2 trains, 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 1 train, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 1 train, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 2 trains, 1 truck, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 2 trains, 1 truck, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 2 trains, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 2 trains, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 2 trains, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 1 train, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 1 train, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 buss, 1 train, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 buss, 1 train, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 buss, 2 trains, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Done: yolo → saved to /content/vehicle_speed_outputs/output_yolo.mp4
# Avg FPS: 53.0
# Avg Speed Estimate: 48.85 km/h
# Total Detections: 22092
# Avg Track Length: 279.65 frames
# Total Runtime: 33.27 seconds
#
#  Running SSD model...
# Done: ssd → saved to /content/vehicle_speed_outputs/output_ssd.mp4
# Avg FPS: 13.93
# Avg Speed Estimate: 72.95 km/h
# Total Detections: 1842
# Avg Track Length: 54.18 frames
# Total Runtime: 124.59 seconds
#
#  Running FRCNN model...
# Done: frcnn → saved to /content/vehicle_speed_outputs/output_frcnn.mp4
# Avg FPS: 0.58
# Avg Speed Estimate: 31.3 km/h
# Total Detections: 36652
# Avg Track Length: 407.24 frames
# Total Runtime: 2953.15 seconds

# %%
import pandas as pd
df = pd.DataFrame(results)
df
# Out:
#    model    fps  avg_speed_kmh  detections  avg_track_length  runtime_sec  \
# 0   yolo  53.00          48.85       22092            279.65        33.27
# 1    ssd  13.93          72.95        1842             54.18       124.59
# 2  frcnn   0.58          31.30       36652            407.24      2953.15
#
#                                         video_path
# 0   /content/vehicle_speed_outputs/output_yolo.mp4
# 1    /content/vehicle_speed_outputs/output_ssd.mp4
# 2  /content/vehicle_speed_outputs/output_frcnn.mp4
